# %%
import numpy as np

from tqdm.notebook import tqdm

# %%
def np_dot(a, b):
  return np.dot(a,b)

def norm(a):
  return np.linalg.norm(a)

# %%
def func(x):
  """
  Функция произвольного
  вида от вектора х.
  """

  x = np.asarray(x).reshape(-1)
  A = np.eye((x.shape[0]))
  b = np.ones_like(x)
  c = 0
  
  return np_dot(np_dot(A,x),x) + np_dot(b,x) + c

# %%
def get_grad(functor, x_0):
  """
  Принимаем на вход функтор и
  координаты точки x_0,
  возвращаем градиент 
  (вектор столбец)
  в этой точке.
  """
  
  eps = 1e-9
  x_0 = np.asarray(x_0, dtype=float).reshape(-1)
  f_grad = np.zeros_like(x_0)

  for i in range(x_0.shape[0]):
    x_plus = x_0.copy()
    x_plus[i] += eps

    x_minus = x_0.copy()
    x_minus[i] -= eps

    f_grad[i] = functor(x_plus) - functor(x_minus)
    f_grad[i] /= 2*eps

  return f_grad.reshape(-1,1)

# %%
import time

# %%
def DFP_method(func, x, eps=1e-6, logging=False):

  # Help function for leraning rate search.
  #
  def one_dim_min(f, x_cur, d_cur):
    """
    One-dimensional minimization rule.

    Ищем lr с помощью градиентного спуска 
     с шагом lrlr, который уменьшается со временем.
    """

    lr = 0.5
    lrlr = 0.1
    f_from_lr = lambda lr: f(x_cur - lr * d_cur)
    fx_prev = np_dot(get_grad(f_from_lr, lr).T, lr) # <f',x>

    for _ in range(1000):          
      th = 1
      lr_d_cur = np.clip(get_grad(f_from_lr, lr), -th, th)[0,0]
      lr = lr - lrlr * lr_d_cur
      fx_next = np_dot(get_grad(f_from_lr, lr).T, lr)
      if fx_next * fx_prev > 0: # Если направление движения не меняется увеличиваем шаг, иначе уменьшаем.
        lrlr *= 1.2
      else:
        lrlr *= 0.6
      fx_prev = fx_next
      # print()
      # print('lr: %.4f' % lr)
      # print('norm lr_d: %.12f' % norm(lr_d_cur))
      # print(eps)
      # print("f\' = %.2f" % fx_next)
      # print('lrlr: %.4f' % lrlr)
      if norm(lr_d_cur) < eps:
        break
      #time.sleep(4)

    return lr


  x = np.asarray(x).reshape(-1,1)

  if logging:
    i = 1

  while norm(get_grad(func, x)) > eps:    

    if logging:
      print('%i-st step of DFP:' % i)
    i+=1

    if logging:
      print("f(x) = %.6f" % func(x))
      #print("f\' = %.6f" % np_dot(get_grad(func, x).T, x))
      print("||f\'|| = %.6f" % norm(get_grad(func, x)))

    Q = np.diag([1.]*x.shape[0])

    x_prev = x
    f_grad_prev = get_grad(func, x_prev)

    d = -np_dot(Q, f_grad_prev)
    lr = one_dim_min(func, x_prev, f_grad_prev) # Ищем длину шага.
    if logging:
      print('lr = %.4f' % lr)
    x_next = x_prev + lr * d  
    f_grad_next = get_grad(func, x_next)

    if logging:
      print('<f\'next, f\'prev> = %.3f' % np_dot(f_grad_next.T, f_grad_prev)) # Проверяем оротогональны ли напр-ия.

    r = x_next - x_prev
    s = f_grad_next - f_grad_prev

    Q_s = np_dot(Q, s)
    Q += np_dot(r, r.T) / np_dot(r.T, s)
    Q -= np_dot(Q_s, Q_s.T) / np_dot(Q_s, s.T)

    x = x_next    

    if logging:
      print('step has been taken', end='\n\n')
  
  if logging:
    print('DFP method converged.', end='\n\n')

  return x

# %%
x_0 = [-5, 10]
x = DFP_method(func, x_0, eps=1e-6, logging=True)
print(func(x), '\n', x)
# Out:
# 1-st step of DFP:
# f(x) = 130.000000
# ||f'|| = 22.847331
# lr = 0.5000
# <f'next, f'prev> = 0.000
# step has been taken
#
# 2-st step of DFP:
# f(x) = -0.500000
# ||f'|| = 0.000015
# lr = 0.5000
# <f'next, f'prev> = 0.000
# step has been taken
#
# DFP method converged.
#
# -0.49999999999999867
#  [[-0.50000002]
#  [-0.50000003]]

# %%
def g_1(x):

  x = np.asarray(x).reshape(2,1)
  const = np.array([1,1]).reshape(2,1)

  return np.float(np_dot(const.T, x))

# %%
def g_2(x):

  x = np.asarray(x).reshape(2,1)
  const = np.array([1,-1]).reshape(2,1)

  return np.float(np_dot(const.T, x))

# %%
def f(x):

  x = np.asarray(x).reshape(2,1)
  const = np.array([10, 9]).reshape(2,1)

  x = x + const
  return np.float(np_dot(x.T, x))

# %%
# def Z_func(x, f, G, r):

#   x = np.asarray(x).reshape(-1,1)
#   p = 10
  
#   rest = 0
#   for i in range(x.shape[0]):
#     rest += np.max(0, -G[i](x))**p

#   return f(x) + r * rest

# %%
def Find_optim(func, x, g_list = [], h_list = [], p=2, r=1, beta=2, eps=1e-6, logging=False):
  """
  x  - начальная точка.
  func - функция, минимум которой мы ищем.
  g_list - список функций-ограничений типа нер-во (>= 0).
  h_list - список функций-ограничений типа равенство.
  p - показатель степени (см. Z_func).
  r - начальное значение параметра штрафа.
  beta - коэф-нт в формуле вычисления параметра штрафа.
  eps  - условия останова, ограничение на ||f'||.
  logging - выводить логи работы или нет.

  return точку x_optim, в кот-ой достигается оптимум func.
  """


  # 2-nd part in Z_func, func - 1st.
  #
  def alpha_func(x, p=p): 

    alpha_func_val = 0    
    for g_func in g_list:
      alpha_func_val += max(0, - g_func(x)) ** p  

    for h_func in h_list:
      alpha_func_val += abs(h_list(x)) ** p
    
    return alpha_func_val

  
  # Main function for finding the optimum.
  #
  def Z_func(x):
    return func(x) + r * alpha_func(x)

  # Function for logging.
  #
  def barriers_logging(x, r):
    print('curr Z_val: %.5f, from' % Z_func(x))
    print('curr optim point: ', end='')
    for x_coor in x: print('%.3f  ' % x_coor, end='')
    print('\nr = %i' % r)
    print('alpha(x) = %.6f' % alpha_func(x))
    print('-'*30)

  if logging:
    print('Search has started!')
    print('-'*30)

  x = DFP_method(Z_func, x, logging=logging)

  if logging:
    barriers_logging(x, r)

  while r*alpha_func(x) > eps:

    r *= beta
    x = DFP_method(Z_func, x, eps, logging=logging)

    if logging:
      barriers_logging(x, r)
    
  if logging:
    print('Search has ended!')
  
  return x

# %%
# %%time
x_0 = np.array([[2],[-1]])

x_optim = Find_optim(func, x_0, [g_1, g_2], eps=1e-6, r=1, logging=True)
x_optim
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# ||f'|| = 0.001188
# lr = 0.2572
# <f'next, f'prev> = -0.000
# step has been taken
#
# 726-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000645
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 727-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001291
# lr = 0.2362
# <f'next, f'prev> = -0.000
# step has been taken
#
# 728-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000538
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 729-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001077
# lr = 0.2824
# <f'next, f'prev> = -0.000
# step has been taken
#
# 730-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000748
# lr = 0.4643
# <f'next, f'prev> = -0.000
# step has been taken
#
# 731-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001335
# lr = 0.2284
# <f'next, f'prev> = -0.000
# step has been taken
#
# 732-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000494
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 733-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000988
# lr = 0.3048
# <f'next, f'prev> = -0.000
# step has been taken
#
# 734-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000819
# lr = 0.4029
# <f'next, f'prev> = -0.000
# step has been taken
#
# 735-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001160
# lr = 0.2624
# <f'next, f'prev> = -0.000
# step has been taken
#
# 736-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000666
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 737-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001333
# lr = 0.2299
# <f'next, f'prev> = -0.000
# step has been taken
#
# 738-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000506
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 739-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001011
# lr = 0.2982
# <f'next, f'prev> = -0.000
# step has been taken
#
# 740-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000798
# lr = 0.4209
# <f'next, f'prev> = -0.000
# step has been taken
#
# 741-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001217
# lr = 0.2505
# <f'next, f'prev> = -0.000
# step has been taken
#
# 742-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000612
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 743-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001225
# lr = 0.2494
# <f'next, f'prev> = -0.000
# step has been taken
#
# 744-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000608
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 745-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001215
# lr = 0.2514
# <f'next, f'prev> = -0.000
# step has been taken
#
# 746-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000618
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 747-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001235
# lr = 0.2465
# <f'next, f'prev> = -0.000
# step has been taken
#
# 748-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000591
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 749-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001183
# lr = 0.2582
# <f'next, f'prev> = -0.000
# step has been taken
#
# 750-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000650
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 751-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001299
# lr = 0.2354
# <f'next, f'prev> = -0.000
# step has been taken
#
# 752-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000536
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 753-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001072
# lr = 0.2839
# <f'next, f'prev> = -0.000
# step has been taken
#
# 754-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000754
# lr = 0.4388
# <f'next, f'prev> = -0.000
# step has been taken
#
# 755-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001231
# lr = 0.2485
# <f'next, f'prev> = -0.000
# step has been taken
#
# 756-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000605
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 757-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001209
# lr = 0.2529
# <f'next, f'prev> = -0.000
# step has been taken
#
# 758-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000626
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 759-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001251
# lr = 0.2435
# <f'next, f'prev> = -0.000
# step has been taken
#
# 760-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000577
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 761-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001154
# lr = 0.2640
# <f'next, f'prev> = -0.000
# step has been taken
#
# 762-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000674
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 763-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001348
# lr = 0.2265
# <f'next, f'prev> = -0.000
# step has been taken
#
# 764-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000484
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 765-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000969
# lr = 0.3088
# <f'next, f'prev> = -0.000
# step has been taken
#
# 766-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000826
# lr = 0.3856
# <f'next, f'prev> = -0.000
# step has been taken
#
# 767-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001085
# lr = 0.2794
# <f'next, f'prev> = -0.000
# step has been taken
#
# 768-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000734
# lr = 0.4708
# <f'next, f'prev> = -0.000
# step has been taken
#
# 769-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001339
# lr = 0.2286
# <f'next, f'prev> = -0.000
# step has been taken
#
# 770-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000498
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 771-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000996
# lr = 0.3026
# <f'next, f'prev> = -0.000
# step has been taken
#
# 772-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000812
# lr = 0.4048
# <f'next, f'prev> = -0.000
# step has been taken
#
# 773-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001160
# lr = 0.2630
# <f'next, f'prev> = -0.000
# step has been taken
#
# 774-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000671
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 775-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001341
# lr = 0.2281
# <f'next, f'prev> = -0.000
# step has been taken
#
# 776-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000495
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 777-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000989
# lr = 0.3038
# <f'next, f'prev> = -0.000
# step has been taken
#
# 778-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000814
# lr = 0.3877
# <f'next, f'prev> = -0.000
# step has been taken
#
# 779-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001080
# lr = 0.2809
# <f'next, f'prev> = -0.000
# step has been taken
#
# 780-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000740
# lr = 0.4648
# <f'next, f'prev> = -0.000
# step has been taken
#
# 781-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001324
# lr = 0.2309
# <f'next, f'prev> = -0.000
# step has been taken
#
# 782-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000510
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 783-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001021
# lr = 0.2954
# <f'next, f'prev> = -0.000
# step has been taken
#
# 784-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000788
# lr = 0.4225
# <f'next, f'prev> = -0.000
# step has been taken
#
# 785-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001210
# lr = 0.2517
# <f'next, f'prev> = -0.000
# step has been taken
#
# 786-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000617
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 787-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001235
# lr = 0.2466
# <f'next, f'prev> = -0.000
# step has been taken
#
# 788-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000592
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 789-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001185
# lr = 0.2578
# <f'next, f'prev> = -0.000
# step has been taken
#
# 790-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000648
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 791-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001296
# lr = 0.2359
# <f'next, f'prev> = -0.000
# step has been taken
#
# 792-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000538
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 793-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001077
# lr = 0.2821
# <f'next, f'prev> = -0.000
# step has been taken
#
# 794-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000746
# lr = 0.4573
# <f'next, f'prev> = -0.000
# step has been taken
#
# 795-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001301
# lr = 0.2351
# <f'next, f'prev> = -0.000
# step has been taken
#
# 796-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000534
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 797-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001068
# lr = 0.2851
# <f'next, f'prev> = -0.000
# step has been taken
#
# 798-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000759
# lr = 0.4386
# <f'next, f'prev> = -0.000
# step has been taken
#
# 799-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001238
# lr = 0.2460
# <f'next, f'prev> = -0.000
# step has been taken
#
# 800-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000589
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 801-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001179
# lr = 0.2586
# <f'next, f'prev> = -0.000
# step has been taken
#
# 802-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000650
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 803-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001300
# lr = 0.2353
# <f'next, f'prev> = -0.000
# step has been taken
#
# 804-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000535
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 805-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001070
# lr = 0.2840
# <f'next, f'prev> = -0.000
# step has been taken
#
# 806-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000753
# lr = 0.4488
# <f'next, f'prev> = -0.000
# step has been taken
#
# 807-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001275
# lr = 0.2396
# <f'next, f'prev> = -0.000
# step has been taken
#
# 808-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000558
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 809-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001115
# lr = 0.2721
# <f'next, f'prev> = -0.000
# step has been taken
#
# 810-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000705
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 811-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001411
# lr = 0.2163
# <f'next, f'prev> = -0.000
# step has been taken
#
# 812-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000420
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 813-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000840
# lr = 0.3821
# <f'next, f'prev> = -0.000
# step has been taken
#
# 814-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001086
# lr = 0.2789
# <f'next, f'prev> = -0.000
# step has been taken
#
# 815-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000731
# lr = 0.4757
# <f'next, f'prev> = -0.000
# step has been taken
#
# 816-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001356
# lr = 0.2253
# <f'next, f'prev> = -0.000
# step has been taken
#
# 817-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000477
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 818-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000954
# lr = 0.3354
# <f'next, f'prev> = -0.000
# step has been taken
#
# 819-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000965
# lr = 0.3110
# <f'next, f'prev> = -0.000
# step has been taken
#
# 820-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000836
# lr = 0.3834
# <f'next, f'prev> = -0.000
# step has been taken
#
# 821-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001087
# lr = 0.2804
# <f'next, f'prev> = -0.000
# step has been taken
#
# 822-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000742
# lr = 0.4703
# <f'next, f'prev> = -0.000
# step has been taken
#
# 823-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001351
# lr = 0.2259
# <f'next, f'prev> = -0.000
# step has been taken
#
# 824-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000481
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 825-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000961
# lr = 0.3110
# <f'next, f'prev> = -0.000
# step has been taken
#
# 826-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000832
# lr = 0.3836
# <f'next, f'prev> = -0.000
# step has been taken
#
# 827-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001084
# lr = 0.2805
# <f'next, f'prev> = -0.000
# step has been taken
#
# 828-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000740
# lr = 0.4649
# <f'next, f'prev> = -0.000
# step has been taken
#
# 829-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001324
# lr = 0.2312
# <f'next, f'prev> = -0.000
# step has been taken
#
# 830-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000513
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 831-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001025
# lr = 0.2933
# <f'next, f'prev> = -0.000
# step has been taken
#
# 832-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000779
# lr = 0.4241
# <f'next, f'prev> = -0.000
# step has been taken
#
# 833-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001203
# lr = 0.2538
# <f'next, f'prev> = -0.000
# step has been taken
#
# 834-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000629
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 835-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001258
# lr = 0.2428
# <f'next, f'prev> = -0.000
# step has been taken
#
# 836-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000574
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 837-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001149
# lr = 0.2653
# <f'next, f'prev> = -0.000
# step has been taken
#
# 838-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000679
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 839-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001359
# lr = 0.2245
# <f'next, f'prev> = -0.000
# step has been taken
#
# 840-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000472
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 841-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000944
# lr = 0.3159
# <f'next, f'prev> = -0.000
# step has been taken
#
# 842-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000845
# lr = 0.3813
# <f'next, f'prev> = -0.000
# step has been taken
#
# 843-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001089
# lr = 0.2792
# <f'next, f'prev> = -0.000
# step has been taken
#
# 844-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000735
# lr = 0.4755
# <f'next, f'prev> = -0.000
# step has been taken
#
# 845-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001363
# lr = 0.2242
# <f'next, f'prev> = -0.000
# step has been taken
#
# 846-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000470
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 847-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000940
# lr = 0.3158
# <f'next, f'prev> = -0.000
# step has been taken
#
# 848-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000842
# lr = 0.3818
# <f'next, f'prev> = -0.000
# step has been taken
#
# 849-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001086
# lr = 0.2794
# <f'next, f'prev> = -0.000
# step has been taken
#
# 850-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000735
# lr = 0.4756
# <f'next, f'prev> = -0.000
# step has been taken
#
# 851-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001363
# lr = 0.2243
# <f'next, f'prev> = -0.000
# step has been taken
#
# 852-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000471
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 853-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000942
# lr = 0.3169
# <f'next, f'prev> = -0.000
# step has been taken
#
# 854-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000849
# lr = 0.3615
# <f'next, f'prev> = -0.000
# step has been taken
#
# 855-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000992
# lr = 0.3034
# <f'next, f'prev> = -0.000
# step has been taken
#
# 856-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000814
# lr = 0.3886
# <f'next, f'prev> = -0.000
# step has been taken
#
# 857-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001084
# lr = 0.2799
# <f'next, f'prev> = -0.000
# step has been taken
#
# 858-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000737
# lr = 0.4708
# <f'next, f'prev> = -0.000
# step has been taken
#
# 859-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001344
# lr = 0.2274
# <f'next, f'prev> = -0.000
# step has been taken
#
# 860-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000489
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 861-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000979
# lr = 0.3069
# <f'next, f'prev> = -0.000
# step has been taken
#
# 862-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000824
# lr = 0.3866
# <f'next, f'prev> = -0.000
# step has been taken
#
# 863-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001087
# lr = 0.2793
# <f'next, f'prev> = -0.000
# step has been taken
#
# 864-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000734
# lr = 0.4756
# <f'next, f'prev> = -0.000
# step has been taken
#
# 865-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001361
# lr = 0.2250
# <f'next, f'prev> = -0.000
# step has been taken
#
# 866-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000476
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 867-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000952
# lr = 0.3132
# <f'next, f'prev> = -0.000
# step has been taken
#
# 868-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000837
# lr = 0.3826
# <f'next, f'prev> = -0.000
# step has been taken
#
# 869-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001085
# lr = 0.2794
# <f'next, f'prev> = -0.000
# step has been taken
#
# 870-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000734
# lr = 0.4708
# <f'next, f'prev> = -0.000
# step has been taken
#
# 871-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001339
# lr = 0.2278
# <f'next, f'prev> = -0.000
# step has been taken
#
# 872-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000492
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 873-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000983
# lr = 0.3053
# <f'next, f'prev> = -0.000
# step has been taken
#
# 874-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000818
# lr = 0.3870
# <f'next, f'prev> = -0.000
# step has been taken
#
# 875-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001081
# lr = 0.2797
# <f'next, f'prev> = -0.000
# step has been taken
#
# 876-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000733
# lr = 0.4651
# <f'next, f'prev> = -0.000
# step has been taken
#
# 877-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001313
# lr = 0.2325
# <f'next, f'prev> = -0.000
# step has been taken
#
# 878-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000519
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 879-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001038
# lr = 0.2915
# <f'next, f'prev> = -0.000
# step has been taken
#
# 880-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000777
# lr = 0.4357
# <f'next, f'prev> = -0.000
# step has been taken
#
# 881-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001255
# lr = 0.2437
# <f'next, f'prev> = -0.000
# step has been taken
#
# 882-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000580
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 883-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001160
# lr = 0.2623
# <f'next, f'prev> = -0.000
# step has been taken
#
# 884-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000666
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 885-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001331
# lr = 0.2289
# <f'next, f'prev> = -0.000
# step has been taken
#
# 886-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000497
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 887-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000994
# lr = 0.3023
# <f'next, f'prev> = -0.000
# step has been taken
#
# 888-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000809
# lr = 0.4058
# <f'next, f'prev> = -0.000
# step has been taken
#
# 889-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001161
# lr = 0.2623
# <f'next, f'prev> = -0.000
# step has been taken
#
# 890-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000666
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 891-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001332
# lr = 0.2289
# <f'next, f'prev> = -0.000
# step has been taken
#
# 892-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000497
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 893-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000995
# lr = 0.3019
# <f'next, f'prev> = -0.000
# step has been taken
#
# 894-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000807
# lr = 0.3896
# <f'next, f'prev> = -0.000
# step has been taken
#
# 895-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001080
# lr = 0.2810
# <f'next, f'prev> = -0.000
# step has been taken
#
# 896-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000740
# lr = 0.4705
# <f'next, f'prev> = -0.000
# step has been taken
#
# 897-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001350
# lr = 0.2261
# <f'next, f'prev> = -0.000
# step has been taken
#
# 898-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000481
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 899-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000962
# lr = 0.3114
# <f'next, f'prev> = -0.000
# step has been taken
#
# 900-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000836
# lr = 0.3829
# <f'next, f'prev> = -0.000
# step has been taken
#
# 901-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001084
# lr = 0.2798
# <f'next, f'prev> = -0.000
# step has been taken
#
# 902-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000736
# lr = 0.4709
# <f'next, f'prev> = -0.000
# step has been taken
#
# 903-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001343
# lr = 0.2276
# <f'next, f'prev> = -0.000
# step has been taken
#
# 904-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000491
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 905-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000983
# lr = 0.3057
# <f'next, f'prev> = -0.000
# step has been taken
#
# 906-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000820
# lr = 0.4032
# <f'next, f'prev> = -0.000
# step has been taken
#
# 907-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001163
# lr = 0.2625
# <f'next, f'prev> = -0.000
# step has been taken
#
# 908-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000669
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 909-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001337
# lr = 0.2285
# <f'next, f'prev> = -0.000
# step has been taken
#
# 910-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000496
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 911-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000992
# lr = 0.3028
# <f'next, f'prev> = -0.000
# step has been taken
#
# 912-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000811
# lr = 0.4050
# <f'next, f'prev> = -0.000
# step has been taken
#
# 913-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001159
# lr = 0.2629
# <f'next, f'prev> = -0.000
# step has been taken
#
# 914-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000669
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 915-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001339
# lr = 0.2284
# <f'next, f'prev> = -0.000
# step has been taken
#
# 916-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000496
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 917-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000992
# lr = 0.3029
# <f'next, f'prev> = -0.000
# step has been taken
#
# 918-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000811
# lr = 0.4041
# <f'next, f'prev> = -0.000
# step has been taken
#
# 919-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001155
# lr = 0.2639
# <f'next, f'prev> = -0.000
# step has been taken
#
# 920-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000674
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 921-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001348
# lr = 0.2262
# <f'next, f'prev> = -0.000
# step has been taken
#
# 922-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000481
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 923-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000963
# lr = 0.3101
# <f'next, f'prev> = -0.000
# step has been taken
#
# 924-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000829
# lr = 0.3844
# <f'next, f'prev> = -0.000
# step has been taken
#
# 925-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001083
# lr = 0.2803
# <f'next, f'prev> = -0.000
# step has been taken
#
# 926-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000738
# lr = 0.4707
# <f'next, f'prev> = -0.000
# step has been taken
#
# 927-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001347
# lr = 0.2261
# <f'next, f'prev> = -0.000
# step has been taken
#
# 928-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000481
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 929-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000961
# lr = 0.3103
# <f'next, f'prev> = -0.000
# step has been taken
#
# 930-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000829
# lr = 0.4011
# <f'next, f'prev> = -0.000
# step has been taken
#
# 931-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001166
# lr = 0.2598
# <f'next, f'prev> = -0.000
# step has been taken
#
# 932-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000651
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 933-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001303
# lr = 0.2352
# <f'next, f'prev> = -0.000
# step has been taken
#
# 934-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000536
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 935-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001072
# lr = 0.2823
# <f'next, f'prev> = -0.000
# step has been taken
#
# 936-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000743
# lr = 0.4702
# <f'next, f'prev> = -0.000
# step has been taken
#
# 937-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001354
# lr = 0.2262
# <f'next, f'prev> = -0.000
# step has been taken
#
# 938-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000484
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 939-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000968
# lr = 0.3089
# <f'next, f'prev> = -0.000
# step has been taken
#
# 940-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000826
# lr = 0.3857
# <f'next, f'prev> = -0.000
# step has been taken
#
# 941-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001085
# lr = 0.2798
# <f'next, f'prev> = -0.000
# step has been taken
#
# 942-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000737
# lr = 0.4705
# <f'next, f'prev> = -0.000
# step has been taken
#
# 943-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001343
# lr = 0.2283
# <f'next, f'prev> = -0.000
# step has been taken
#
# 944-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000497
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 945-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000993
# lr = 0.3029
# <f'next, f'prev> = -0.000
# step has been taken
#
# 946-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000812
# lr = 0.4046
# <f'next, f'prev> = -0.000
# step has been taken
#
# 947-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001159
# lr = 0.2624
# <f'next, f'prev> = -0.000
# step has been taken
#
# 948-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000666
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 949-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001332
# lr = 0.2295
# <f'next, f'prev> = -0.000
# step has been taken
#
# 950-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000502
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 951-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001004
# lr = 0.2998
# <f'next, f'prev> = -0.000
# step has been taken
#
# 952-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000802
# lr = 0.4066
# <f'next, f'prev> = -0.000
# step has been taken
#
# 953-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001154
# lr = 0.2645
# <f'next, f'prev> = -0.000
# step has been taken
#
# 954-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000678
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 955-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001356
# lr = 0.2258
# <f'next, f'prev> = -0.000
# step has been taken
#
# 956-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000481
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 957-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000962
# lr = 0.3099
# <f'next, f'prev> = -0.000
# step has been taken
#
# 958-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000827
# lr = 0.3858
# <f'next, f'prev> = -0.000
# step has been taken
#
# 959-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001087
# lr = 0.2803
# <f'next, f'prev> = -0.000
# step has been taken
#
# 960-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000741
# lr = 0.4704
# <f'next, f'prev> = -0.000
# step has been taken
#
# 961-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001351
# lr = 0.2262
# <f'next, f'prev> = -0.000
# step has been taken
#
# 962-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000482
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 963-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000964
# lr = 0.3095
# <f'next, f'prev> = -0.000
# step has been taken
#
# 964-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000826
# lr = 0.4017
# <f'next, f'prev> = -0.000
# step has been taken
#
# 965-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001165
# lr = 0.2615
# <f'next, f'prev> = -0.000
# step has been taken
#
# 966-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000663
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 967-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001326
# lr = 0.2309
# <f'next, f'prev> = -0.000
# step has been taken
#
# 968-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000511
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 969-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001022
# lr = 0.2956
# <f'next, f'prev> = -0.000
# step has been taken
#
# 970-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000791
# lr = 0.4219
# <f'next, f'prev> = -0.000
# step has been taken
#
# 971-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001211
# lr = 0.2518
# <f'next, f'prev> = -0.000
# step has been taken
#
# 972-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000619
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 973-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001237
# lr = 0.2461
# <f'next, f'prev> = -0.000
# step has been taken
#
# 974-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000589
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 975-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001179
# lr = 0.2585
# <f'next, f'prev> = -0.000
# step has been taken
#
# 976-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000649
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 977-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001299
# lr = 0.2353
# <f'next, f'prev> = -0.000
# step has been taken
#
# 978-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000535
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 979-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001070
# lr = 0.2833
# <f'next, f'prev> = -0.000
# step has been taken
#
# 980-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000749
# lr = 0.4641
# <f'next, f'prev> = -0.000
# step has been taken
#
# 981-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001336
# lr = 0.2284
# <f'next, f'prev> = -0.000
# step has been taken
#
# 982-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000495
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 983-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000990
# lr = 0.3041
# <f'next, f'prev> = -0.000
# step has been taken
#
# 984-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000816
# lr = 0.3877
# <f'next, f'prev> = -0.000
# step has been taken
#
# 985-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001083
# lr = 0.2796
# <f'next, f'prev> = -0.000
# step has been taken
#
# 986-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000734
# lr = 0.4794
# <f'next, f'prev> = -0.000
# step has been taken
#
# 987-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001377
# lr = 0.2229
# <f'next, f'prev> = -0.000
# step has been taken
#
# 988-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000465
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 989-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000929
# lr = 0.3410
# <f'next, f'prev> = -0.000
# step has been taken
#
# 990-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000972
# lr = 0.3076
# <f'next, f'prev> = -0.000
# step has been taken
#
# 991-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000822
# lr = 0.4024
# <f'next, f'prev> = -0.000
# step has been taken
#
# 992-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001163
# lr = 0.2616
# <f'next, f'prev> = -0.000
# step has been taken
#
# 993-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000662
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 994-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001325
# lr = 0.2294
# <f'next, f'prev> = -0.000
# step has been taken
#
# 995-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000499
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 996-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000998
# lr = 0.3021
# <f'next, f'prev> = -0.000
# step has been taken
#
# 997-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000811
# lr = 0.4051
# <f'next, f'prev> = -0.000
# step has been taken
#
# 998-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001160
# lr = 0.2629
# <f'next, f'prev> = -0.000
# step has been taken
#
# 999-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000669
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1000-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001339
# lr = 0.2279
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1001-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000492
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1002-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000985
# lr = 0.3044
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1003-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000814
# lr = 0.4039
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1004-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001158
# lr = 0.2621
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1005-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000663
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1006-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001326
# lr = 0.2306
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1007-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000509
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1008-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001017
# lr = 0.2963
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1009-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000791
# lr = 0.4080
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1010-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001146
# lr = 0.2660
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1011-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000683
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1012-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001366
# lr = 0.2229
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1013-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000461
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1014-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000922
# lr = 0.3206
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1015-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000851
# lr = 0.3615
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1016-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000995
# lr = 0.3012
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1017-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000803
# lr = 0.4052
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1018-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001149
# lr = 0.2653
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1019-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000680
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1020-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001361
# lr = 0.2256
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1021-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000481
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1022-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000961
# lr = 0.3109
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1023-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000832
# lr = 0.3842
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1024-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001086
# lr = 0.2800
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1025-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000738
# lr = 0.4649
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1026-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001321
# lr = 0.2311
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1027-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000510
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1028-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001021
# lr = 0.2961
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1029-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000792
# lr = 0.4219
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1030-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001214
# lr = 0.2513
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1031-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000616
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1032-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001232
# lr = 0.2480
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1033-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000602
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1034-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001203
# lr = 0.2531
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1035-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000624
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1036-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001248
# lr = 0.2448
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1037-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000585
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1038-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001170
# lr = 0.2606
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1039-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000660
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1040-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001320
# lr = 0.2309
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1041-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000509
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1042-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001017
# lr = 0.2954
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1043-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000785
# lr = 0.4230
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1044-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001208
# lr = 0.2526
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1045-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000623
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1046-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001246
# lr = 0.2455
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1047-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000589
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1048-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001179
# lr = 0.2585
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1049-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000650
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1050-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001299
# lr = 0.2358
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1051-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000539
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1052-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001078
# lr = 0.2812
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1053-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000741
# lr = 0.4705
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1054-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001350
# lr = 0.2267
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1055-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000486
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1056-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000972
# lr = 0.3094
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1057-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000832
# lr = 0.4006
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1058-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001168
# lr = 0.2598
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1059-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000653
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1060-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001305
# lr = 0.2342
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1061-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000529
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1062-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001058
# lr = 0.2869
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1063-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000763
# lr = 0.4379
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1064-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001242
# lr = 0.2452
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1065-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000585
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1066-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001170
# lr = 0.2606
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1067-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000659
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1068-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001318
# lr = 0.2311
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1069-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000509
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1070-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001019
# lr = 0.2965
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1071-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000794
# lr = 0.4081
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1072-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001150
# lr = 0.2647
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1073-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000676
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1074-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001352
# lr = 0.2261
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1075-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000482
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1076-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000964
# lr = 0.3108
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1077-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000834
# lr = 0.3829
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1078-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001082
# lr = 0.2809
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1079-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000741
# lr = 0.4578
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1080-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001295
# lr = 0.2359
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1081-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000538
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1082-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001075
# lr = 0.2818
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1083-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000743
# lr = 0.4703
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1084-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001353
# lr = 0.2255
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1085-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000478
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1086-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000955
# lr = 0.3136
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1087-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000842
# lr = 0.3821
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1088-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001089
# lr = 0.2789
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1089-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000733
# lr = 0.4758
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1090-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001360
# lr = 0.2240
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1091-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000468
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1092-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000936
# lr = 0.3166
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1093-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000842
# lr = 0.3821
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1094-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001088
# lr = 0.2794
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1095-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000736
# lr = 0.4651
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1096-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001318
# lr = 0.2317
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1097-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000514
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1098-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001029
# lr = 0.2928
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1099-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000778
# lr = 0.4241
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1100-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001203
# lr = 0.2541
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1101-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000631
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1102-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001261
# lr = 0.2420
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1103-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000570
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1104-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001140
# lr = 0.2667
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1105-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000684
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1106-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001368
# lr = 0.2230
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1107-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000462
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1108-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000924
# lr = 0.3212
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1109-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000857
# lr = 0.3787
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1110-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001090
# lr = 0.2796
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1111-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000738
# lr = 0.4753
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1112-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001367
# lr = 0.2236
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1113-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000467
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1114-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000935
# lr = 0.3171
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1115-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000844
# lr = 0.3813
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1116-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001086
# lr = 0.2793
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1117-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000734
# lr = 0.4795
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1118-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001378
# lr = 0.2227
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1119-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000463
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1120-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000926
# lr = 0.3199
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1121-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000851
# lr = 0.3798
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1122-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001089
# lr = 0.2786
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1123-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000731
# lr = 0.4709
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1124-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001335
# lr = 0.2284
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1125-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000495
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1126-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000989
# lr = 0.3041
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1127-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000816
# lr = 0.4034
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1128-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001159
# lr = 0.2633
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1129-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000672
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1130-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001344
# lr = 0.2274
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1131-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000490
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1132-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000980
# lr = 0.3055
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1133-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000817
# lr = 0.4031
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1134-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001159
# lr = 0.2626
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1135-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000667
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1136-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001334
# lr = 0.2296
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1137-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000504
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1138-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001008
# lr = 0.2988
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1139-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000799
# lr = 0.4071
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1140-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001153
# lr = 0.2642
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1141-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000675
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1142-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001350
# lr = 0.2262
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1143-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000482
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1144-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000964
# ...
#
# 1331-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000494
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1332-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000987
# lr = 0.3050
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1333-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000820
# lr = 0.4028
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1334-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001161
# lr = 0.2622
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1335-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000666
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1336-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001331
# lr = 0.2298
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1337-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000505
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1338-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001009
# lr = 0.2984
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1339-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000798
# lr = 0.4072
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1340-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001151
# lr = 0.2635
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1341-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000669
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1342-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001338
# lr = 0.2280
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1343-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000493
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1344-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000986
# lr = 0.3041
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1345-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000813
# lr = 0.4040
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1346-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001157
# lr = 0.2641
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1347-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000676
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1348-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001352
# lr = 0.2259
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1349-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000481
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1350-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000962
# lr = 0.3111
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1351-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000833
# lr = 0.3832
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1352-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001083
# lr = 0.2810
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1353-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000742
# lr = 0.4646
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1354-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001327
# lr = 0.2302
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1355-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000506
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1356-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001011
# lr = 0.2977
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1357-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000795
# lr = 0.4081
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1358-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001152
# lr = 0.2651
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1359-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000681
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1360-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001361
# lr = 0.2247
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1361-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000474
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1362-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000948
# lr = 0.3139
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1363-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000837
# lr = 0.3832
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1364-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001087
# lr = 0.2797
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1365-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000738
# lr = 0.4651
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1366-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001321
# lr = 0.2313
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1367-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000512
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1368-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001025
# lr = 0.2949
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1369-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000789
# lr = 0.4227
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1370-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001211
# lr = 0.2525
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1371-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000624
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1372-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001247
# lr = 0.2446
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1373-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000584
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1374-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001167
# lr = 0.2610
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1375-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000660
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1376-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001321
# lr = 0.2323
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1377-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000520
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1378-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001040
# lr = 0.2914
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1379-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000778
# lr = 0.4358
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1380-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001257
# lr = 0.2429
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1381-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000575
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1382-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001151
# lr = 0.2643
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1383-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000674
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1384-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001349
# lr = 0.2263
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1385-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000483
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1386-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000966
# lr = 0.3098
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1387-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000829
# lr = 0.3849
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1388-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001086
# lr = 0.2798
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1389-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000737
# lr = 0.4857
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1390-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001411
# lr = 0.2161
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1391-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000419
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1392-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000838
# lr = 0.3828
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1393-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001086
# lr = 0.2800
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1394-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000738
# lr = 0.4706
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1395-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001346
# lr = 0.2271
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1396-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000488
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1397-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000976
# lr = 0.3063
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1398-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000818
# lr = 0.4034
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1399-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001162
# lr = 0.2625
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1400-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000668
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1401-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001336
# lr = 0.2295
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1402-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000503
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1403-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001007
# lr = 0.2996
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1404-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000803
# lr = 0.4057
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1405-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001152
# lr = 0.2641
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1406-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000674
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1407-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001347
# lr = 0.2272
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1408-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000489
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1409-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000978
# lr = 0.3069
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1410-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000823
# lr = 0.4025
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1411-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001164
# lr = 0.2619
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1412-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000665
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1413-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001330
# lr = 0.2297
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1414-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000503
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1415-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001007
# lr = 0.2996
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1416-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000803
# lr = 0.4063
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1417-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001154
# lr = 0.2644
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1418-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000677
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1419-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001353
# lr = 0.2256
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1420-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000479
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1421-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000957
# lr = 0.3119
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1422-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000834
# lr = 0.3829
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1423-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001082
# lr = 0.2804
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1424-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000739
# lr = 0.4647
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1425-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001321
# lr = 0.2312
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1426-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000511
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1427-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001023
# lr = 0.2951
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1428-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000788
# lr = 0.4228
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1429-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001212
# lr = 0.2519
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1430-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000620
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1431-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001240
# lr = 0.2471
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1432-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000598
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1433-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001197
# lr = 0.2553
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1434-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000636
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1435-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001273
# lr = 0.2404
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1436-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000563
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1437-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001125
# lr = 0.2708
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1438-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.000703
# lr = 0.5000
# <f'next, f'prev> = -0.000
# step has been taken
#
# 1439-st step of DFP:
# f(x) = -0.166667
# ||f'|| = 0.001406
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-063c25df01d0> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'x_0 = np.array([[2],[-1]])\n\nx_optim = Find_optim(func, x_0, [g_1, g_2], eps=1e-6, r=1, logging=True)\nx_optim')
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-55-104d15852fd8> in Find_optim(func, x, g_list, h_list, p, r, beta, eps, logging)
#      48     print('-'*30)
#      49
# ---> 50   x = DFP_method(Z_func, x, logging=logging)
#      51
#      52   if logging:
#
# <ipython-input-50-3d14fff78f25> in DFP_method(func, x, eps, logging)
#      61
#      62     d = -np_dot(Q, f_grad_prev)
# ---> 63     lr = one_dim_min(func, x_prev, f_grad_prev) # Ищем длину шага.
#      64     if logging:
#      65       print('lr = %.4f' % lr)
#
# <ipython-input-50-3d14fff78f25> in one_dim_min(f, x_cur, d_cur)
#      18     for _ in range(1000):
#      19       th = 1
# ---> 20       lr_d_cur = np.clip(get_grad(f_from_lr, lr), -th, th)[0,0]
#      21       lr = lr - lrlr * lr_d_cur
#      22       fx_next = np_dot(get_grad(f_from_lr, lr).T, lr)
#
# <ipython-input-5-b5b08c5a2487> in get_grad(functor, x_0)
#      19     x_minus[i] -= eps
#      20
# ---> 21     f_grad[i] = functor(x_plus) - functor(x_minus)
#      22     f_grad[i] /= 2*eps
#      23
#
# <ipython-input-50-3d14fff78f25> in <lambda>(lr)
#      13     lr = 0.5
#      14     lrlr = 0.1
# ---> 15     f_from_lr = lambda lr: f(x_cur - lr * d_cur)
#      16     fx_prev = np_dot(get_grad(f_from_lr, lr).T, lr) # <f',x>
#      17
#
# <ipython-input-55-104d15852fd8> in Z_func(x)
#      32   #
#      33   def Z_func(x):
# ---> 34     return func(x) + r * alpha_func(x)
#      35
#      36   # Function for logging.
#
# <ipython-input-3-310412b93a67> in func(x)
#       7   x = np.asarray(x).reshape(-1)
#       8   A = np.eye((x.shape[0]))
# ----> 9   b = np.ones_like(x)
#      10   c = 0
#      11
#
# <__array_function__ internals> in ones_like(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in ones_like(a, dtype, order, subok, shape)
#     276
#     277     """
# --> 278     res = empty_like(a, dtype=dtype, order=order, subok=subok, shape=shape)
#     279     multiarray.copyto(res, 1, casting='unsafe')
#     280     return res
#
# <__array_function__ internals> in empty_like(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/multiarray.py in empty_like(prototype, dtype, order, subok, shape)
#     140
#     141     """
# --> 142     return (prototype,)
#     143
#     144
#
# KeyboardInterrupt:
